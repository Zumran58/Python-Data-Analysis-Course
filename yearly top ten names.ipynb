# %%
import math
import collections

import numpy as np
import pandas as pd
import matplotlib.pyplot as pp

# %matplotlib inline

# %%
pd.options.display.max_rows = 10

# %%
allyears = pd.read_csv('allyears.csv.gz')

# %%
allyears_byyear = allyears.set_index(['sex','year']).sort_index()

# %%
allyears_byyear.loc['M', 2018].sort_values('number', ascending = False)
# Out:
#              name  number
# sex year
# M   2018     Liam   19837
#     2018     Noah   18267
#     2018  William   14516
#     2018    James   13525
#     2018   Oliver   13389
# ...           ...     ...
#     2018   Gaylon       5
#     2018   Gavynn       5
#     2018    Gavon       5
#     2018   Gaurav       5
#     2018    Zzyzx       5
#
# [14004 rows x 2 columns]

# %%
allyears_byyear.loc['M', 2018].sort_values('number', ascending = False).head(10)
# Out:
#               name  number
# sex year
# M   2018      Liam   19837
#     2018      Noah   18267
#     2018   William   14516
#     2018     James   13525
#     2018    Oliver   13389
#     2018  Benjamin   13381
#     2018    Elijah   12886
#     2018     Lucas   12585
#     2018     Mason   12435
#     2018     Logan   12352

# %%
allyears_byyear.loc['F',2018].sort_values('number', ascending = False).head(10)
# Out:
#                name  number
# sex year
# F   2018       Emma   18688
#     2018     Olivia   17921
#     2018        Ava   14924
#     2018   Isabella   14464
#     2018     Sophia   13928
#     2018  Charlotte   12940
#     2018        Mia   12642
#     2018     Amelia   12301
#     2018     Harper   10582
#     2018     Evelyn   10376

# %%
allyears_byyear.loc['F', 2018].sort_values('number', ascending = False).head(10).reset_index().name
# Out:
# 0         Emma
# 1       Olivia
# 2          Ava
# 3     Isabella
# 4       Sophia
# 5    Charlotte
# 6          Mia
# 7       Amelia
# 8       Harper
# 9       Evelyn
# Name: name, dtype: object

# %%
def getyear(sex, year):
    return(allyears_byyear.loc[sex,year]
              .sort_values('number', ascending = False)
              .head(10)
              .reset_index()
              .name)

# %%
pd.DataFrame({year:getyear('M',year) for year in range(2010, 2019)})
# Out:
#         2010       2011       2012       2013       2014       2015      2016  \
# 0      Jacob      Jacob      Jacob       Noah       Noah       Noah      Noah
# 1      Ethan      Mason      Mason      Jacob       Liam       Liam      Liam
# 2    Michael    William      Ethan       Liam      Mason      Mason   William
# 3     Jayden     Jayden       Noah      Mason      Jacob      Jacob     Mason
# 4    William       Noah    William    William    William    William     James
# 5  Alexander    Michael       Liam      Ethan      Ethan      Ethan  Benjamin
# 6       Noah      Ethan    Michael    Michael    Michael      James     Jacob
# 7     Daniel  Alexander     Jayden  Alexander  Alexander  Alexander   Michael
# 8      Aiden      Aiden  Alexander     Jayden      James    Michael    Elijah
# 9    Anthony     Daniel      Aiden     Daniel     Daniel   Benjamin     Ethan
#
#        2017      2018
# 0      Liam      Liam
# 1      Noah      Noah
# 2   William   William
# 3     James     James
# 4     Logan    Oliver
# 5  Benjamin  Benjamin
# 6     Mason    Elijah
# 7    Elijah     Lucas
# 8    Oliver     Mason
# 9     Jacob     Logan

# %%
def plotname(sex, name):
    data = allyears.query('sex == #sex and name - #name')
    
    pp.plot(data.year, data.number, label = name)
    pp.axis(xmin = 1880, xmax = 2018)

# %%
pp.figure(figsize = (12,2.5))

for name in getyear('M', 2018):
    plotname('M', name)
pp.legend()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-15-ff7c274616fd>", line 4, in <module>
#     plotname('M', name)
#
#   File "<ipython-input-14-a3ec0705795c>", line 2, in plotname
#     data = allyears.query('sex == #sex and name - #name')
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 371, in visit
#     raise e
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "C:\Users\Zumran\anaconda3\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     sex ==#sex and name - #name
#                                ^
# SyntaxError: Python keyword not valid identifier in numexpr query

# %%
list(getyear('M',2018))
# Out:
# ['Liam',
#  'Noah',
#  'William',
#  'James',
#  'Oliver',
#  'Benjamin',
#  'Elijah',
#  'Lucas',
#  'Mason',
#  'Logan']

# %%
pp.figure(figsize = (12,2.5))

for name in ['Liam', 'Noah', 'Oliver', 'Benjamin', 'Elijah', 'Lucas','Mason', 'Logan']:
    plotname('M',name)
pp.legend()
# Out:
# Traceback (most recent call last):
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3331, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-22-7cdc480c89d4>", line 4, in <module>
#     plotname('M',name)
#
#   File "<ipython-input-14-a3ec0705795c>", line 2, in plotname
#     data = allyears.query('sex == #sex and name - #name')
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\frame.py", line 3231, in query
#     res = self.eval(expr, **kwargs)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\frame.py", line 3346, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\eval.py", line 332, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 764, in __init__
#     self.terms = self.parse()
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 781, in parse
#     return self._visitor.visit(self.expr)
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 371, in visit
#     raise e
#
#   File "C:\Users\Zumran\anaconda3\lib\site-packages\pandas\core\computation\expr.py", line 367, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#
#   File "C:\Users\Zumran\anaconda3\lib\ast.py", line 35, in parse
#     return compile(source, filename, mode, PyCF_ONLY_AST)
#
#   File "<unknown>", line 1
#     sex ==#sex and name - #name
#                                ^
# SyntaxError: Python keyword not valid identifier in numexpr query

# %%
alltime_f = allyears_byyear.loc['F'].groupby('name').sum().sort_values('number', ascending = False).head(10)

# %%
alltime_f
# Out:
#             number
# name
# Mary       4125675
# Elizabeth  1638349
# Patricia   1572016
# Jennifer   1467207
# Linda      1452668
# Barbara    1434397
# Margaret   1248985
# Susan      1121703
# Dorothy    1107635
# Sarah      1077746

# %%
pp.figure(figsize = (12,2.5))

for name in alltime_f_index:
    plotname('F', name)
pp.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-8e35435bbcd4> in <module>
#       1 pp.figure(figsize = (12,2.5))
#       2
# ----> 3 for name in alltime_f_index:
#       4     plotname('F', name)
#       5 pp.legend()
#
# NameError: name 'alltime_f_index' is not defined
